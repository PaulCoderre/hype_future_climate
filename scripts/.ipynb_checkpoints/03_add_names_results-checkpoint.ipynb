# %%
import os
import glob
import shutil
import re

# %%
directory_list= './directories.txt' # path to datatool directories list
run_directory = '../../results/bias_correction/no_drizz_full_bias_corr/' # path to directory containing model run output folders

# %%
# Read the list of paths from directories.txt
with open(directory_list, 'r') as f:
    directories = [line.strip() for line in f.readlines()]

# %%
# Get list of files in run_directory, sort alphabetically, and exclude hidden files (starting with '.')
results_list = sorted([f for f in os.listdir(run_directory) 
                       if os.path.isfile(os.path.join(run_directory, f)) and not f.startswith('.')])

# %%
# Exclusion list
exclude_strings = [
    'CanESM5', 'CNRM-CM6-1', 'EC-Earth3', 'IPSL-CM6A-LR',
    'UKESM1-0-LL', 'NorESM2-MM', 'EC-Earth3-CC', 'NESM3',
    'EC-Earth3-Veg', 'INM-CM4-8', 'TaiESM1', 'ssp585'
]

# %%
# Dictionary to store valid matches
valid_matches = {}

# Process each file
for file in results_list:
    # Extract the number prefix (first two digits)
    index = int(file.split("_")[0])  # Convert to integer for indexing
    
    # Ensure index is within the directory list bounds
    if index < len(directories):
        directory = directories[index]  # Get corresponding directory
        
        # Check if directory contains any excluded strings
        if not any(exclude in directory for exclude in exclude_strings):
            valid_matches[file] = directory

            parts = directory.split('/')
            middle_part = '_'.join(parts[2:-2]).replace('/', '_')

            # Construct new filename
            base_name, ext = os.path.splitext(file)  # Get name and extension
            new_filename = f"{base_name}_{middle_part}{ext}"  # Append middle part

            # Get full paths
            old_path = os.path.join(run_directory, file)
            new_path = os.path.join(run_directory, new_filename)
        
            # Rename file
            os.rename(old_path, new_path)
            print(f"Renamed: {file} -> {new_filename}")
# Out:
# Renamed: 03_0058208.txt -> 03_0058208_outs_INM_INM-CM5-0_ssp370.txt
# Renamed: 03_0058308.txt -> 03_0058308_outs_INM_INM-CM5-0_ssp370.txt
# Renamed: 03_timeFCON_DD.txt -> 03_timeFCON_DD_outs_INM_INM-CM5-0_ssp370.txt
# Renamed: 05_0058208.txt -> 05_0058208_outs_INM_INM-CM5-0_ssp245.txt
# Renamed: 05_0058308.txt -> 05_0058308_outs_INM_INM-CM5-0_ssp245.txt
# Renamed: 05_timeFCON_DD.txt -> 05_timeFCON_DD_outs_INM_INM-CM5-0_ssp245.txt
# Renamed: 09_0058208.txt -> 09_0058208_outs_NCC_NorESM2-LM_ssp370.txt
# Renamed: 09_0058308.txt -> 09_0058308_outs_NCC_NorESM2-LM_ssp370.txt
# Renamed: 09_timeFCON_DD.txt -> 09_timeFCON_DD_outs_NCC_NorESM2-LM_ssp370.txt
# Renamed: 11_0058208.txt -> 11_0058208_outs_NCC_NorESM2-LM_ssp245.txt
# Renamed: 11_0058308.txt -> 11_0058308_outs_NCC_NorESM2-LM_ssp245.txt
# Renamed: 11_timeFCON_DD.txt -> 11_timeFCON_DD_outs_NCC_NorESM2-LM_ssp245.txt
# Renamed: 15_0058208.txt -> 15_0058208_outs_NOAA-GFDL_GFDL-ESM4_ssp245.txt
# Renamed: 15_0058308.txt -> 15_0058308_outs_NOAA-GFDL_GFDL-ESM4_ssp245.txt
# Renamed: 15_timeFCON_DD.txt -> 15_timeFCON_DD_outs_NOAA-GFDL_GFDL-ESM4_ssp245.txt
# Renamed: 16_0058208.txt -> 16_0058208_outs_NOAA-GFDL_GFDL-ESM4_ssp370.txt
# Renamed: 16_0058308.txt -> 16_0058308_outs_NOAA-GFDL_GFDL-ESM4_ssp370.txt
# Renamed: 16_timeFCON_DD.txt -> 16_timeFCON_DD_outs_NOAA-GFDL_GFDL-ESM4_ssp370.txt
# Renamed: 18_0058208.txt -> 18_0058208_outs_CAS_FGOALS-g3_ssp370.txt
# Renamed: 18_0058308.txt -> 18_0058308_outs_CAS_FGOALS-g3_ssp370.txt
# Renamed: 18_timeFCON_DD.txt -> 18_timeFCON_DD_outs_CAS_FGOALS-g3_ssp370.txt
# Renamed: 20_0058208.txt -> 20_0058208_outs_CAS_FGOALS-g3_ssp245.txt
# Renamed: 20_0058308.txt -> 20_0058308_outs_CAS_FGOALS-g3_ssp245.txt
# Renamed: 20_timeFCON_DD.txt -> 20_timeFCON_DD_outs_CAS_FGOALS-g3_ssp245.txt
# Renamed: 23_0058208.txt -> 23_0058208_outs_CMCC_CMCC-ESM2_ssp370.txt
# Renamed: 23_0058308.txt -> 23_0058308_outs_CMCC_CMCC-ESM2_ssp370.txt
# Renamed: 23_timeFCON_DD.txt -> 23_timeFCON_DD_outs_CMCC_CMCC-ESM2_ssp370.txt
# Renamed: 24_0058208.txt -> 24_0058208_outs_CMCC_CMCC-ESM2_ssp245.txt
# Renamed: 24_0058308.txt -> 24_0058308_outs_CMCC_CMCC-ESM2_ssp245.txt
# Renamed: 24_timeFCON_DD.txt -> 24_timeFCON_DD_outs_CMCC_CMCC-ESM2_ssp245.txt
# Renamed: 26_0058208.txt -> 26_0058208_outs_CSIRO_ACCESS-ESM1-5_ssp245.txt
# Renamed: 26_0058308.txt -> 26_0058308_outs_CSIRO_ACCESS-ESM1-5_ssp245.txt
# Renamed: 26_timeFCON_DD.txt -> 26_timeFCON_DD_outs_CSIRO_ACCESS-ESM1-5_ssp245.txt
# Renamed: 27_0058208.txt -> 27_0058208_outs_CSIRO_ACCESS-ESM1-5_ssp370.txt
# Renamed: 27_0058308.txt -> 27_0058308_outs_CSIRO_ACCESS-ESM1-5_ssp370.txt
# Renamed: 27_timeFCON_DD.txt -> 27_timeFCON_DD_outs_CSIRO_ACCESS-ESM1-5_ssp370.txt
# Renamed: 29_0058208.txt -> 29_0058208_outs_DKRZ_MPI-ESM1-2-HR_ssp245.txt
# Renamed: 29_0058308.txt -> 29_0058308_outs_DKRZ_MPI-ESM1-2-HR_ssp245.txt
# Renamed: 29_timeFCON_DD.txt -> 29_timeFCON_DD_outs_DKRZ_MPI-ESM1-2-HR_ssp245.txt
# Renamed: 31_0058208.txt -> 31_0058208_outs_DKRZ_MPI-ESM1-2-HR_ssp370.txt
# Renamed: 31_0058308.txt -> 31_0058308_outs_DKRZ_MPI-ESM1-2-HR_ssp370.txt
# Renamed: 31_timeFCON_DD.txt -> 31_timeFCON_DD_outs_DKRZ_MPI-ESM1-2-HR_ssp370.txt
# Renamed: 33_0058208.txt -> 33_0058208_outs_BCC_BCC-CSM2-MR_ssp370.txt
# Renamed: 33_0058308.txt -> 33_0058308_outs_BCC_BCC-CSM2-MR_ssp370.txt
# Renamed: 33_timeFCON_DD.txt -> 33_timeFCON_DD_outs_BCC_BCC-CSM2-MR_ssp370.txt
# Renamed: 34_0058208.txt -> 34_0058208_outs_BCC_BCC-CSM2-MR_ssp245.txt
# Renamed: 34_0058308.txt -> 34_0058308_outs_BCC_BCC-CSM2-MR_ssp245.txt
# Renamed: 34_timeFCON_DD.txt -> 34_timeFCON_DD_outs_BCC_BCC-CSM2-MR_ssp245.txt
# Renamed: 39_0058208.txt -> 39_0058208_outs_CNRM-CERFACS_CNRM-ESM2-1_ssp245.txt
# Renamed: 39_0058308.txt -> 39_0058308_outs_CNRM-CERFACS_CNRM-ESM2-1_ssp245.txt
# Renamed: 39_timeFCON_DD.txt -> 39_timeFCON_DD_outs_CNRM-CERFACS_CNRM-ESM2-1_ssp245.txt
# Renamed: 40_0058208.txt -> 40_0058208_outs_CNRM-CERFACS_CNRM-ESM2-1_ssp370.txt
# Renamed: 40_0058308.txt -> 40_0058308_outs_CNRM-CERFACS_CNRM-ESM2-1_ssp370.txt
# Renamed: 40_timeFCON_DD.txt -> 40_timeFCON_DD_outs_CNRM-CERFACS_CNRM-ESM2-1_ssp370.txt
# Renamed: 44_0058208.txt -> 44_0058208_outs_MPI-M_MPI-ESM1-2-LR_ssp370.txt
# Renamed: 44_0058308.txt -> 44_0058308_outs_MPI-M_MPI-ESM1-2-LR_ssp370.txt
# Renamed: 44_timeFCON_DD.txt -> 44_timeFCON_DD_outs_MPI-M_MPI-ESM1-2-LR_ssp370.txt
# Renamed: 46_0058208.txt -> 46_0058208_outs_MPI-M_MPI-ESM1-2-LR_ssp245.txt
# Renamed: 46_0058308.txt -> 46_0058308_outs_MPI-M_MPI-ESM1-2-LR_ssp245.txt
# Renamed: 46_timeFCON_DD.txt -> 46_timeFCON_DD_outs_MPI-M_MPI-ESM1-2-LR_ssp245.txt
# Renamed: 47_0058208.txt -> 47_0058208_outs_MIROC_MIROC6_ssp370.txt
# Renamed: 47_0058308.txt -> 47_0058308_outs_MIROC_MIROC6_ssp370.txt
# Renamed: 47_timeFCON_DD.txt -> 47_timeFCON_DD_outs_MIROC_MIROC6_ssp370.txt
# Renamed: 48_0058208.txt -> 48_0058208_outs_MIROC_MIROC6_ssp245.txt
# Renamed: 48_0058308.txt -> 48_0058308_outs_MIROC_MIROC6_ssp245.txt
# Renamed: 48_timeFCON_DD.txt -> 48_timeFCON_DD_outs_MIROC_MIROC6_ssp245.txt
# Renamed: 50_0058208.txt -> 50_0058208_outs_MIROC_MIROC-ES2L_ssp370.txt
# Renamed: 50_0058308.txt -> 50_0058308_outs_MIROC_MIROC-ES2L_ssp370.txt
# Renamed: 50_timeFCON_DD.txt -> 50_timeFCON_DD_outs_MIROC_MIROC-ES2L_ssp370.txt
# Renamed: 51_0058208.txt -> 51_0058208_outs_MIROC_MIROC-ES2L_ssp245.txt
# Renamed: 51_0058308.txt -> 51_0058308_outs_MIROC_MIROC-ES2L_ssp245.txt
# Renamed: 51_timeFCON_DD.txt -> 51_timeFCON_DD_outs_MIROC_MIROC-ES2L_ssp245.txt
# Renamed: 53_0058208.txt -> 53_0058208_outs_MRI_MRI-ESM2-0_ssp370.txt
# Renamed: 53_0058308.txt -> 53_0058308_outs_MRI_MRI-ESM2-0_ssp370.txt
# Renamed: 53_timeFCON_DD.txt -> 53_timeFCON_DD_outs_MRI_MRI-ESM2-0_ssp370.txt
# Renamed: 55_0058208.txt -> 55_0058208_outs_MRI_MRI-ESM2-0_ssp245.txt
# Renamed: 55_0058308.txt -> 55_0058308_outs_MRI_MRI-ESM2-0_ssp245.txt
# Renamed: 55_timeFCON_DD.txt -> 55_timeFCON_DD_outs_MRI_MRI-ESM2-0_ssp245.txt
# Renamed: 56_0058208.txt -> 56_0058208_outs_CSIRO-ARCCSS_ACCESS-CM2_ssp245.txt
# Renamed: 56_0058308.txt -> 56_0058308_outs_CSIRO-ARCCSS_ACCESS-CM2_ssp245.txt
# Renamed: 56_timeFCON_DD.txt -> 56_timeFCON_DD_outs_CSIRO-ARCCSS_ACCESS-CM2_ssp245.txt
# Renamed: 57_0058208.txt -> 57_0058208_outs_CSIRO-ARCCSS_ACCESS-CM2_ssp370.txt
# Renamed: 57_0058308.txt -> 57_0058308_outs_CSIRO-ARCCSS_ACCESS-CM2_ssp370.txt
# Renamed: 57_timeFCON_DD.txt -> 57_timeFCON_DD_outs_CSIRO-ARCCSS_ACCESS-CM2_ssp370.txt
